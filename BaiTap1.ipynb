# %%
# %matplotlib inline
import pandas as pd
import geopandas
pd.options.display.max_rows = 20

# %%
bien = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/Bien.shp")
duong = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/Duong.shp")
song = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/Song.shp")
huyen = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/huyen.shp")
tinh = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/Tinh.shp")
xa = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/xa.shp")
UBND_tinh = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/UBND_tinh.shp")
UBND_huyen = geopandas.read_file("data/Bai1_Nhap va Trinh bay DL/UBND_huyen.shp")

# %%
ax = tinh.plot(legend='true')
huyen.plot(ax=ax)
xa.plot(ax=ax, color = 'grey')
song.plot(ax=ax, color = 'green')
bien.plot(ax=ax)
duong.plot(ax=ax, color = 'red')
UBND_tinh.plot(ax=ax)
UBND_huyen.plot(ax=ax)
#ax.set(xlim=(-20, 60), ylim=(-40, 40))
ax.set(xlim=(500000, 700000), ylim=(2250000, 2350000))
# Out:
# [(2250000, 2350000), (500000, 700000)]
